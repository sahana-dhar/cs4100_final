# %%
# CNN from MRI images (before HMM pipeline)
# Load MRI images from Google Drive using nibabel
# Train CNN to classify Clinical Dementia Rating state from brain scan
# Remove final layer → extract 8192-dim feature vector per image
# Run PCA → make 20 dims
#  Save feature vectors for HMM

# %%
import nibabel as nib                      # load .img / .nii MRI files
import numpy as np                        
import pandas as pd                       
from PIL import Image                      # resize image slices
import torch                               # deep learning framework
import torch.nn as nn                      # build CNN layers
import torch.optim as optim                #  optimizer
from torch.utils.data import DataLoader, TensorDataset  # batch loading
from sklearn.decomposition import PCA      # reduce feature size
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
